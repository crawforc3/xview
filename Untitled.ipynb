# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cv2
import json
# %matplotlib inline

# %%
# !ls -1 train_images/ | head
# Out:
# 100.tif
# 102.tif
# 1036.tif
# 1037.tif
# 1042.tif
# 1044.tif
# 1046.tif
# 1048.tif
# 1049.tif
# 104.tif

# %%
plt.imshow(cv2.imread('train_images/10.tif'))

# %%
def get_labels(fname="xView_train.geojson"):
    with open(fname) as f:
        data = json.load(f)
    
    coords = np.zeros((len(data['features']),4))
    chips = np.zeros((len(data['features'])),dtype="object")
    classes = np.zeros((len(data['features'])))
    for i in range(len(data['features'])):
        if data['features'][i]['properties']['bounds_imcoords'] != []:
            b_id = data['features'][i]['properties']['image_id']
            val = np.array([int(num) for num in data['features'][i]['properties']['bounds_imcoords'].split(",")])
            chips[i] = b_id
            classes[i] = data['features'][i]['properties']['type_id']
            coords[i] = val
        else:
            chips[i] = 'None'
    return coords, chips, classes

# %%
coords, chips, classes = get_labels()

# %%
# coords is an array
# ?coords

# %% [markdown]
# Type:            ndarray
#
# String form:
#
# [[2712. 1145. 2746. 1177.]
#
#  [2720. 2233. 2760. 2288.]
#
#  [2687. 1338. 2740. 1399.]
#
#  ...
#
#  [2106.  361. 2124.  379.]
#
#  [1917.   38. 1958.   64.]
#
#  [2323.   55. 2349.   74.]]

# %%
# ?chips

# %% [markdown]
# Type:            ndarray
#
# String form:     ['2355.tif' '2355.tif' '2355.tif' ... '389.tif' '389.tif' '389.tif']

# %%
# ?classes

# %% [markdown]
# Type:            ndarray
#
# String form:     [73. 73. 73. ... 73. 73. 73.]
