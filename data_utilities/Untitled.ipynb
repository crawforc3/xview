# %%
import json

# %%
geojsonfile = '../xView_train.geojson'
with open(geojsonfile, 'r') as infile:
    j = json.load(infile)

# %%
j.keys()
# Out:
# dict_keys(['crs', 'type', 'features', 'name'])

# %%
for i in range(len(j['features'])):
    #print(j['features'][i]['properties']['type_id'])
    if j['features'][i]['properties']['type_id'] == (75):
        [print(j, v) for j,v in j['features'][i]['properties'].items()]
# Out:
# bounds_imcoords 2580,1142,2944,1370
# edited_by wwkarlanicole
# cat_id 104001002878AB00
# type_id 75
# ingest_time 2017/08/14 18:24:08.349+00
# index_right 2308
# image_id 2308.tif
# point_geom 0101000020E610000085BBBECD19CC3C4096B48B4D0B7F4440
# feature_id 693184
# grid_file Grid3.shp
# bounds_imcoords 2579,176,2719,256
# edited_by wwlisandromenendez
# cat_id 104001002878AB00
# type_id 75
# ingest_time 2017/07/14 15:22:44.677+00
# index_right 2308
# image_id 2308.tif
# point_geom 0101000020E61000008AA1B9C800CC3C4082A30C0A7E7F4440
# feature_id 106898
# grid_file Grid3.shp
# bounds_imcoords 658,809,782,878
# edited_by wwgiovanisantiago
# cat_id 104001002878AB00
# type_id 75
# ingest_time 2017/07/10 18:03:27.097+00
# index_right 2313
# image_id 2313.tif
# point_geom 0101000020E6100000BD41C00C67CA3C40064166F55F804440
# feature_id 106740
# grid_file Grid3.shp
# bounds_imcoords 94,1568,559,1826
# edited_by wwvictorrosario
# cat_id 1040010026542100
# type_id 75
# ...
